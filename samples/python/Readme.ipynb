# %% [markdown]
# ## **Описание API**

# %% [markdown]
# **API ИС "Учёт ремонтов"** - это [gRPC-интерфейс](https://grpc.io/docs/) для взаимодействия с информационной системой.
#
# ##### **API ИС "Учёт ремонтов" позволяет вам:**
# * Получать информацию о кустовых объектах
# * Добавлять кустовые объекты
# * Редактировать объекты
# * Удалять кустовые объекты
# * Получать информацию о заявках на ремонт
# * Добавлять заявки на ремонт
# * Удалять заявки на ремонт
# * Редактировать заявки на ремонт
# * Получать данные о наработке объекта
# * Добавлять данные о наработке объекта
# * Редактировать данные о наработке объекта
# * Удалять данные о наработке объекта
# * Получать данные телеметрии
# * Загружать данные телеметрии
# * Запрашивать токены доступа к сервисам API
#
# Вся работа **API ИС "Учёт ремонтов"** происходит по протоколу gRPC, документацию которого можно найти по ссылке: https://grpc.io/docs/.
#
#
#
#
# #### Авторизация в **API ИС "Учёт ремонтов"**
# Для использования API ИС "Учёт ремонтов" требуется получить **токен доступа**, токен доступа определяет к каким сервисам и методам клиент имеет доступ.
#
# Для работы с **API ИС "Учёт ремонтов"** требуется передавать токен доступа в metadata каждого запроса.
#
# Формат заголовка: Authorization: Bearer [токен доступ]
#
# **Например**: Authorization: Bearer
# *"eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..goQEHMzxCpSzPi7_gwkqtwqcNL6exvCPGk8j0izOVOg"*
#
#
#
#
# #### Адрес сервиса **API ИС "Учёт ремонтов"**
# Все вызовы сервиса выполняются по адресу:
#  **http://51.250.109.24:5000**
#
#
#
#
# #### Языки програмирования для взаимодействия с **API ИС "Учёт ремонтов"**
#     C#
#     C++
#     Dart
#     Go
#     Java
#     Kotlin
#     Node
#     Objective-C
#     PHP
#     Python
#     Ruby
#
#   ## Пример обращения к сервису на языке Python
#
#   Установите модули:
#
# python -m pip install --upgrade pip
#
# python -m pip install grpcio
#
# python -m pip install grpcio-tools

# %%
import grpc
from messages_pb2 import *
import requests_pb2
from objects_pb2 import *
from objects_pb2_grpc import *

# %%
from importlib import metadata


host='51.250.109.24:5000'
auth_token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..goQEHMzxCpSzPi7_gwkqtwqcNL6exvCPGk8j0izOVOg'
metadata = []
metadata.append(('authorization', 'Bearer ' + auth_token ))

channel = grpc.insecure_channel(host)

# %%
stub =  ObjectsServStub( channel)

# %%
empty = requests_pb2.messages__pb2.Empty()
objs=stub.GetAll(empty,timeout=2000, metadata = metadata)
for itm in objs.items:
    print(itm)
# Out:
# Kod: 3
# Name: "Кустовой объект № 3"
# TekNar: 951
# LastTo {
#   seconds: 1641340799
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 3000
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 7.52723551
# DateFrom {
#   seconds: 1646265599
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1660175999
#   nanos: 999999900
# }
# SredNarPlan: 7.87320662
# Id: 8
# TrainingFrom {
#   seconds: 1641167999
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656806399
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 1656806399
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: 2
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 4
# Name: "Кустовой объект № 4"
# TekNar: 507
# LastTo {
#   seconds: 1641167999
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 1500
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 3.57125044
# DateFrom {
#   seconds: 1641167999
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1667087999
#   nanos: 999999900
# }
# SredNarPlan: 3.84041977
# Status: 1
# Id: 6
# TrainingFrom {
#   seconds: 1641167999
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656806399
#   nanos: 999999900
# }
# WarningType: 2
# WarningTime {
#   seconds: 1660700400
# }
# WarningFrom {
#   seconds: 1656806399
#   nanos: 999999900
# }
# WarningSensor: 1
# ErrorRate: 2
# ErrorPeriod: 60
# HasValue: true
#
# Kod: 6
# Name: "Кустовой объект № 6"
# TekNar: 1280
# LastTo {
#   seconds: 1641081599
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 1500
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 8.32971478
# DateFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1660175999
#   nanos: 999999900
# }
# SredNarPlan: 6.2196517
# Status: 1
# Id: 2
# TrainingFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: 2
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 13
# Name: "Кустовой объект № 13"
# TekNar: 435
# LastTo {
#   seconds: 1641081599
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 700
# PlanYear: 2500
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 2.86306024
# DateFrom {
#   seconds: 1646179199
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1665359999
#   nanos: 999999900
# }
# SredNarPlan: 4.85618782
# Id: 7
# TrainingFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: 2
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 1
# Name: "Кустовой объект № 1"
# TekNar: 1050
# LastTo {
#   seconds: 1641254399
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 1500
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 7.67766857
# DateFrom {
#   seconds: 1643932799
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1661385599
#   nanos: 999999900
# }
# SredNarPlan: 5.8936286
# Status: 1
# Id: 18
# TrainingFrom {
#   seconds: 1641254399
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656892799
#   nanos: 999999900
# }
# WarningType: 1
# WarningTime {
#   seconds: 1657459260
# }
# WarningFrom {
#   seconds: 1656892799
#   nanos: 999999900
# }
# WarningSensor: 1
# ErrorRate: 2
# ErrorPeriod: 60
# HasValue: true
#
# Kod: 2
# Name: "Кустовой объект № 2"
# TekNar: 1450
# LastTo {
#   seconds: 1641167999
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 1500
# Koef2: 0.5
# Koef1: 1.04
# SredNar: 11.404974
# DateFrom {
#   seconds: 1646265599
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1655423999
#   nanos: 999999900
# }
# SredNarPlan: 7.7572813
# Id: 16
# TrainingFrom {
#   seconds: 1641167999
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656806399
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 1656806399
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: 2
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 8
# Name: "Кустовой объект № 8"
# TekNar: 160
# LastTo {
#   seconds: 1660867199
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 1500
# Koef2: 0.5
# Koef1: 1.05
# DateFrom {
#   seconds: 1643932799
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1681862399
#   nanos: 999999900
# }
# SredNarPlan: 4.1095891
# Id: 15
# TrainingFrom {
#   seconds: 1641254399
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656892799
#   nanos: 999999900
# }
# WarningType: 2
# WarningTime {
#   seconds: 1660570080
# }
# WarningFrom {
#   seconds: 1656892799
#   nanos: 999999900
# }
# WarningSensor: 3
# ErrorRate: 2
# ErrorPeriod: 60
# HasValue: true
#
# Kod: 10
# Name: "Кустовой объект № 10"
# TekNar: 200
# LastTo {
#   seconds: 1641081599
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 1500
# Koef2: 0.5
# Koef1: 1.05
# DateFrom {
#   seconds: 1643759999
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1662076799
#   nanos: 999999900
# }
# SredNarPlan: 4.1095891
# Id: 1
# TrainingFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: 2
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 12
# Name: "Кустовой объект № 12"
# TekNar: 1440
# LastTo {
#   seconds: 1641081599
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 2000
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 7.9398365
# DateFrom {
#   seconds: 1643759999
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1656633599
#   nanos: 999999900
# }
# SredNarPlan: 6.70964432
# Id: 14
# TrainingFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningType: 2
# WarningTime {
#   seconds: 1660570080
# }
# WarningFrom {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningSensor: 3
# ErrorRate: 2
# ErrorPeriod: 60
# HasValue: true
#
# Kod: 14
# Name: "Кустовой объект № 14"
# TekNar: 420
# LastTo {
#   seconds: 1641081599
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 700
# PlanYear: 2500
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 2.77376986
# DateFrom {
#   seconds: 1646179199
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1665964799
#   nanos: 999999900
# }
# SredNarPlan: 4.81154251
# Id: 17
# TrainingFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: 2
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 15
# Name: "Кустовой объект № 15"
# TekNar: 1037
# LastTo {
#   seconds: 1641081599
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 2000
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 6.75025034
# DateFrom {
#   seconds: 1646179199
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1661990399
#   nanos: 999999900
# }
# SredNarPlan: 6.11485147
# Id: 19
# TrainingFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: 2
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 17
# Name: "Кустовой объект № 17"
# TekNar: 1116
# LastTo {
#   seconds: 1641081599
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 4000
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 9.07925606
# DateFrom {
#   seconds: 1648857599
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1654041599
#   nanos: 999999900
# }
# SredNarPlan: 10.0190802
# Id: 10
# TrainingFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: 2
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 18
# Name: "Кустовой объект № 18"
# TekNar: 1234
# LastTo {
#   seconds: 1641081599
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 5000
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 10.0699282
# DateFrom {
#   seconds: 1648857599
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1654041599
#   nanos: 999999900
# }
# SredNarPlan: 11.8842793
# Id: 12
# TrainingFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: 2
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 7
# Name: "Кустовой объект № 7"
# TekNar: 2132
# LastTo {
#   seconds: 1641081599
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 1500
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 13.1002951
# DateFrom {
#   seconds: 1643759999
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1652486399
#   nanos: 999999900
# }
# SredNarPlan: 8.60494137
# Id: 4
# TrainingFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningType: 3
# WarningTime {
#   seconds: 1657976460
# }
# WarningFrom {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningSensor: 2
# ErrorRate: 2
# ErrorPeriod: 60
# HasValue: true
#
# Kod: 9
# Name: "Кустовой объект № 9"
# TekNar: 180
# LastTo {
#   seconds: 1641167999
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 1500
# Koef2: 0.5
# Koef1: 1.05
# DateFrom {
#   seconds: 1643846399
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1662163199
#   nanos: 999999900
# }
# SredNarPlan: 4.1095891
# Id: 5
# TrainingFrom {
#   seconds: 1641167999
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656806399
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 1656806399
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: 2
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 11
# Name: "Кустовой объект № 11"
# TekNar: 960
# LastTo {
#   seconds: 1641081599
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 2000
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 5.29322433
# DateFrom {
#   seconds: 1643759999
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1661990399
#   nanos: 999999900
# }
# SredNarPlan: 5.38633823
# Id: 3
# TrainingFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningType: 4
# WarningTime {
#   seconds: 1660187640
# }
# WarningFrom {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningSensor: 2
# ErrorRate: 2
# ErrorPeriod: 60
# HasValue: true
#
# Kod: 16
# Name: "Кустовой объект № 16"
# TekNar: 1240
# LastTo {
#   seconds: 1641081599
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1022
# PlanYear: 4000
# Koef2: 0.2
# Koef1: 1.05
# SredNar: 10.0880632
# DateFrom {
#   seconds: 1648857599
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1654041599
#   nanos: 999999900
# }
# SredNarPlan: 10.7847357
# Id: 20
# TrainingFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: 2
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 19
# Name: "Кустовой объект № 19"
# TekNar: 1760
# LastTo {
#   seconds: 1641081599
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 5000
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 11.4144564
# DateFrom {
#   seconds: 1646179199
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1651363199
#   nanos: 999999900
# }
# SredNarPlan: 12.5565434
# Id: 9
# TrainingFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: 2
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 20
# Name: "Кустовой объект № 20"
# TekNar: 2611
# LastTo {
#   seconds: 1641081599
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 5000
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 17.1205616
# DateFrom {
#   seconds: 1646179199
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1648771199
#   nanos: 999999900
# }
# SredNarPlan: 15.4095955
# Status: 1
# Id: 11
# TrainingFrom {
#   seconds: 1641081599
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 1656719999
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: 2
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 21
# TekNar: -1
# LastTo {
#   seconds: 86399
#   nanos: 999999900
# }
# ToTime: -1
# ToNar: -1
# PlanYear: -1
# Koef2: -1
# Koef1: -1
# SredNar: -1
# DateFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# NarFrom: -1
# NextTo {
#   seconds: 86399
#   nanos: 999999900
# }
# SredNarPlan: -1
# Status: -1
# Id: 43
# TrainingFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: -1
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 22
# TekNar: -1
# LastTo {
#   seconds: 86399
#   nanos: 999999900
# }
# ToTime: -1
# ToNar: -1
# PlanYear: -1
# Koef2: -1
# Koef1: -1
# SredNar: -1
# DateFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# NarFrom: -1
# NextTo {
#   seconds: 86399
#   nanos: 999999900
# }
# SredNarPlan: -1
# Status: -1
# Id: 44
# TrainingFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: -1
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 23
# TekNar: -1
# LastTo {
#   seconds: 86399
#   nanos: 999999900
# }
# ToTime: -1
# ToNar: -1
# PlanYear: -1
# Koef2: -1
# Koef1: -1
# SredNar: -1
# DateFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# NarFrom: -1
# NextTo {
#   seconds: 86399
#   nanos: 999999900
# }
# SredNarPlan: -1
# Status: -1
# Id: 45
# TrainingFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: -1
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 24
# Name: "тест"
# TekNar: 7
# LastTo {
#   seconds: 1662940799
#   nanos: 999999900
# }
# ToTime: 5
# ToNar: 6
# PlanYear: 6
# Koef2: 5
# Koef1: 9
# SredNar: 8
# DateFrom {
#   seconds: 1663545599
#   nanos: 999999900
# }
# NarFrom: 3
# NextTo {
#   seconds: 86399
#   nanos: 999999900
# }
# SredNarPlan: -1
# Status: -1
# Id: 46
# TrainingFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: -1
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 25
# Name: "Объект №test"
# LastTo {
#   seconds: 1664409599
#   nanos: 999999900
# }
# ToTime: 1
# ToNar: 2
# PlanYear: 8
# Koef2: -1
# Koef1: -1
# SredNar: 2
# DateFrom {
#   seconds: 1662508799
#   nanos: 999999900
# }
# NarFrom: 3
# NextTo {
#   seconds: 1663372799
#   nanos: 999999900
# }
# SredNarPlan: -1
# Status: -1
# Id: 47
# TrainingFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: -1
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 26
# Name: "adfgh"
# TekNar: -1
# LastTo {
#   seconds: 86399
#   nanos: 999999900
# }
# ToTime: -1
# ToNar: -1
# PlanYear: -1
# Koef2: -1
# Koef1: -1
# SredNar: -1
# DateFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# NarFrom: -1
# NextTo {
#   seconds: 86399
#   nanos: 999999900
# }
# SredNarPlan: -1
# Status: -1
# Id: 50
# TrainingFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: -1
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 27
# Name: "122"
# TekNar: -1
# LastTo {
#   seconds: 2303942399
#   nanos: 999999900
# }
# ToTime: -1
# ToNar: -1
# PlanYear: -1
# Koef2: -1
# Koef1: -1
# SredNar: -1
# DateFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# NarFrom: -1
# NextTo {
#   seconds: 86399
#   nanos: 999999900
# }
# SredNarPlan: -1
# Status: -1
# Id: 51
# TrainingFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 86399
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: -1
# ErrorPeriod: -1
# HasValue: true
#
# Kod: 5
# Name: "Кустовой объект № 5"
# TekNar: 642
# LastTo {
#   seconds: 1641254399
#   nanos: 999999900
# }
# ToTime: 300
# ToNar: 1000
# PlanYear: 1500
# Koef2: 0.5
# Koef1: 1.05
# SredNar: 4.27215672
# DateFrom {
#   seconds: 1641254399
#   nanos: 999999900
# }
# NextTo {
#   seconds: 1667174399
#   nanos: 999999900
# }
# SredNarPlan: 4.19087267
# Status: 1
# Id: 13
# TrainingFrom {
#   seconds: 1641254399
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 1656892799
#   nanos: 999999900
# }
# WarningType: 2
# WarningTime {
#   seconds: 1660572300
# }
# WarningFrom {
#   seconds: 1656892799
#   nanos: 999999900
# }
# WarningSensor: 2
# ErrorRate: 2
# ErrorPeriod: 60
# HasValue: true
#
# Kod: 28
# Name: "sdfghjj"
# TekNar: -1
# LastTo {
#   seconds: 13651199
#   nanos: 999999900
# }
# ToTime: -1
# ToNar: -1
# PlanYear: -1
# Koef2: -1
# Koef1: -1
# SredNar: -1
# DateFrom {
#   seconds: 172799
#   nanos: 999999900
# }
# NarFrom: -1
# NextTo {
#   seconds: 172799
#   nanos: 999999900
# }
# SredNarPlan: -1
# Status: -1
# Id: 53
# TrainingFrom {
#   seconds: 172799
#   nanos: 999999900
# }
# TrainingTo {
#   seconds: 172799
#   nanos: 999999900
# }
# WarningTime {
# }
# WarningFrom {
#   seconds: 172799
#   nanos: 999999900
# }
# WarningSensor: -1
# ErrorRate: -1
# ErrorPeriod: -1
# HasValue: true
